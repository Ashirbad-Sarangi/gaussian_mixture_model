# %%
import pandas as analytics
import numpy as maths
from math import exp

# %%
df_raw = analytics.read_csv('Data1.csv')
df_raw = df_raw.drop('Unnamed: 0',axis=1)
df_raw.columns = ["x","y"]
df_raw
# Out:
#              x         y
# 0     1.004939  2.319887
# 1     3.412653 -1.637157
# 2     7.483318 -1.399250
# 3     0.702826  2.038150
# 4     0.287620  2.191703
# ...        ...       ...
# 1595  1.475069  2.329653
# 1596  4.277030  2.183024
# 1597  0.814996  2.246927
# 1598  7.999698 -1.811024
# 1599  4.007795  0.121834
#
# [1600 rows x 2 columns]

# %%
df_raw.rename(columns = {0:"x",1:"y"})
# Out:
#              0         1
# 0     1.004939  2.319887
# 1     3.412653 -1.637157
# 2     7.483318 -1.399250
# 3     0.702826  2.038150
# 4     0.287620  2.191703
# ...        ...       ...
# 1595  1.475069  2.329653
# 1596  4.277030  2.183024
# 1597  0.814996  2.246927
# 1598  7.999698 -1.811024
# 1599  4.007795  0.121834
#
# [1600 rows x 2 columns]

# %%
df_raw.plot(x = 'x', y = 'y', kind = 'scatter', figsize = (15,10))
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
cluster_number = 4

# %%
mean = maths.random.random(size = cluster_number)
probability = maths.ones(shape = means.shape) / cluster_number
sigma = maths.random.random(size = cluster_number)

# %%
means = mean
probabilities = probability
sigmas = sigma

old_means = means - 1
old_probabilities = probabilities - 1
old_sigmas = sigmas - 1

tolerance = 1e-1

# %%
p = []
while maths.norm(means - old_means) < tolerance :
    old_means = means
    old_probabilities = probabilities
    old_sigmas = sigmas

    for i in range(cluster_number) :
        p.append([])
        for j in range(df_raw.shape[0]) :
            conditional_probability = 1/abs(sigma')
            p[i].append(probability*conditional_probability)/
